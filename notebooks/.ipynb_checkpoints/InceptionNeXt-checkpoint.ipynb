# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import cv2

# %%
files=[]
paths = []
for dirname, _, filenames in os.walk('../../data/siim-acr-pneumothorax/png_images'):
    for filename in filenames:
        path = os.path.join(dirname, filename)    
        paths.append(path)
        files.append(filename)

# %%
imageData=pd.read_csv('../../data/siim-acr-pneumothorax/stage_1_train_images.csv')
imageData
# Out:
#              new_filename                                            ImageId  \
# 0          0_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.5597.151787518...
# 1          1_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.12515.15178752...
# 2          2_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.4904.151787518...
# 3          3_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.32579.15178751...
# 4          4_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.1314.151787516...
# ...                   ...                                                ...
# 10670  10670_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.32459.15178751...
# 10671  10671_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.4461.151787518...
# 10672  10672_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.32730.15178751...
# 10673  10673_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.13252.15178752...
# 10674  10674_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.12050.15178752...
#
#        has_pneumo
# 0               0
# 1               0
# 2               1
# 3               1
# 4               1
# ...           ...
# 10670           1
# 10671           1
# 10672           0
# 10673           0
# 10674           0
#
# [10675 rows x 3 columns]

# %%
print(imageData['has_pneumo'].unique().tolist())
#imageData=imageData[imageData['has_pneumo']==1].reset_index(drop=True)
print(len(imageData))
display(imageData)
# Out:
# [0, 1]
# 10675
#              new_filename                                            ImageId  \
# 0          0_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.5597.151787518...
# 1          1_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.12515.15178752...
# 2          2_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.4904.151787518...
# 3          3_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.32579.15178751...
# 4          4_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.1314.151787516...
# ...                   ...                                                ...
# 10670  10670_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.32459.15178751...
# 10671  10671_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.4461.151787518...
# 10672  10672_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.32730.15178751...
# 10673  10673_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.13252.15178752...
# 10674  10674_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.12050.15178752...
#
#        has_pneumo
# 0               0
# 1               0
# 2               1
# 3               1
# 4               1
# ...           ...
# 10670           1
# 10671           1
# 10672           0
# 10673           0
# 10674           0
#
# [10675 rows x 3 columns]

# %%
imageData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10675 entries, 0 to 10674
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   new_filename  10675 non-null  object
#  1   ImageId       10675 non-null  object
#  2   has_pneumo    10675 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 250.3+ KB

# %%
"""
InceptionNeXt implementation, paper: https://arxiv.org/abs/2303.16900

Some code is borrowed from timm: https://github.com/huggingface/pytorch-image-models
"""

from functools import partial

import torch
import torch.nn as nn

from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
from timm.models.helpers import checkpoint_seq
from timm.models.layers import trunc_normal_, DropPath
from timm.models.registry import register_model
from timm.models.layers.helpers import to_2tuple


class InceptionDWConv2d(nn.Module):
    """ Inception depthweise convolution
    """
    def __init__(self, in_channels, square_kernel_size=3, band_kernel_size=11, branch_ratio=0.125):
        super().__init__()
        
        gc = int(in_channels * branch_ratio) # channel numbers of a convolution branch
        self.dwconv_hw = nn.Conv2d(gc, gc, square_kernel_size, padding=square_kernel_size//2, groups=gc)
        self.dwconv_w = nn.Conv2d(gc, gc, kernel_size=(1, band_kernel_size), padding=(0, band_kernel_size//2), groups=gc)
        self.dwconv_h = nn.Conv2d(gc, gc, kernel_size=(band_kernel_size, 1), padding=(band_kernel_size//2, 0), groups=gc)
        self.split_indexes = (in_channels - 3 * gc, gc, gc, gc)
        
    def forward(self, x):
        x_id, x_hw, x_w, x_h = torch.split(x, self.split_indexes, dim=1)
        return torch.cat(
            (x_id, self.dwconv_hw(x_hw), self.dwconv_w(x_w), self.dwconv_h(x_h)), 
            dim=1,
        )


class ConvMlp(nn.Module):
    """ MLP using 1x1 convs that keeps spatial dims
    copied from timm: https://github.com/huggingface/pytorch-image-models/blob/v0.6.11/timm/models/layers/mlp.py
    """
    def __init__(
            self, in_features, hidden_features=None, out_features=None, act_layer=nn.ReLU,
            norm_layer=None, bias=True, drop=0.):
        super().__init__()
        out_features = out_features or in_features
        hidden_features = hidden_features or in_features
        bias = to_2tuple(bias)

        self.fc1 = nn.Conv2d(in_features, hidden_features, kernel_size=1, bias=bias[0])
        self.norm = norm_layer(hidden_features) if norm_layer else nn.Identity()
        self.act = act_layer()
        self.drop = nn.Dropout(drop)
        self.fc2 = nn.Conv2d(hidden_features, out_features, kernel_size=1, bias=bias[1])

    def forward(self, x):
        x = self.fc1(x)
        x = self.norm(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        return x


class MlpHead(nn.Module):
    """ MLP classification head
    """
    def __init__(self, dim, num_classes=1, mlp_ratio=3, act_layer=nn.GELU,
        norm_layer=partial(nn.LayerNorm, eps=1e-6), drop=0., bias=True):
        super().__init__()
        hidden_features = int(mlp_ratio * dim)
        self.fc1 = nn.Linear(dim, hidden_features, bias=bias)
        self.act = act_layer()
        self.norm = norm_layer(hidden_features)
        self.fc2 = nn.Linear(hidden_features, num_classes, bias=bias)
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        x = x.mean((2, 3)) # global average pooling
        x = self.fc1(x)
        x = self.act(x)
        x = self.norm(x)
        x = self.drop(x)
        x = self.fc2(x)
        return x


class MetaNeXtBlock(nn.Module):
    """ MetaNeXtBlock Block
    Args:
        dim (int): Number of input channels.
        drop_path (float): Stochastic depth rate. Default: 0.0
        ls_init_value (float): Init value for Layer Scale. Default: 1e-6.
    """

    def __init__(
            self,
            dim,
            token_mixer=nn.Identity,
            norm_layer=nn.BatchNorm2d,
            mlp_layer=ConvMlp,
            mlp_ratio=4,
            act_layer=nn.GELU,
            ls_init_value=1e-6,
            drop_path=0.,
            
    ):
        super().__init__()
        self.token_mixer = token_mixer(dim)
        self.norm = norm_layer(dim)
        self.mlp = mlp_layer(dim, int(mlp_ratio * dim), act_layer=act_layer)
        self.gamma = nn.Parameter(ls_init_value * torch.ones(dim)) if ls_init_value else None
        self.drop_path = DropPath(drop_path) if drop_path > 0. else nn.Identity()

    def forward(self, x):
        shortcut = x
        x = self.token_mixer(x)
        x = self.norm(x)
        x = self.mlp(x)
        if self.gamma is not None:
            x = x.mul(self.gamma.reshape(1, -1, 1, 1))
        x = self.drop_path(x) + shortcut
        return x


class MetaNeXtStage(nn.Module):
    def __init__(
            self,
            in_chs,
            out_chs,
            ds_stride=2,
            depth=2,
            drop_path_rates=None,
            ls_init_value=1.0,
            token_mixer=nn.Identity,
            act_layer=nn.GELU,
            norm_layer=None,
            mlp_ratio=4,
    ):
        super().__init__()
        self.grad_checkpointing = False
        if ds_stride > 1:
            self.downsample = nn.Sequential(
                norm_layer(in_chs),
                nn.Conv2d(in_chs, out_chs, kernel_size=ds_stride, stride=ds_stride),
            )
        else:
            self.downsample = nn.Identity()

        drop_path_rates = drop_path_rates or [0.] * depth
        stage_blocks = []
        for i in range(depth):
            stage_blocks.append(MetaNeXtBlock(
                dim=out_chs,
                drop_path=drop_path_rates[i],
                ls_init_value=ls_init_value,
                token_mixer=token_mixer,
                act_layer=act_layer,
                norm_layer=norm_layer,
                mlp_ratio=mlp_ratio,
            ))
            in_chs = out_chs
        self.blocks = nn.Sequential(*stage_blocks)

    def forward(self, x):
        x = self.downsample(x)
        if self.grad_checkpointing and not torch.jit.is_scripting():
            x = checkpoint_seq(self.blocks, x)
        else:
            x = self.blocks(x)
        return x


class MetaNeXt(nn.Module):
    r""" MetaNeXt
        A PyTorch impl of : `InceptionNeXt: When Inception Meets ConvNeXt`  - https://arxiv.org/pdf/2203.xxxxx.pdf

    Args:
        in_chans (int): Number of input image channels. Default: 3
        num_classes (int): Number of classes for classification head. Default: 1
        depths (tuple(int)): Number of blocks at each stage. Default: (3, 3, 9, 3)
        dims (tuple(int)): Feature dimension at each stage. Default: (96, 192, 384, 768)
        token_mixers: Token mixer function. Default: nn.Identity
        norm_layer: Normalziation layer. Default: nn.BatchNorm2d
        act_layer: Activation function for MLP. Default: nn.GELU
        mlp_ratios (int or tuple(int)): MLP ratios. Default: (4, 4, 4, 3)
        head_fn: classifier head
        drop_rate (float): Head dropout rate
        drop_path_rate (float): Stochastic depth rate. Default: 0.
        ls_init_value (float): Init value for Layer Scale. Default: 1e-6.
    """

    def __init__(
            self,
            in_chans=1,
            num_classes=1,
            depths=(3, 3, 9, 3),
            dims=(96, 192, 384, 768),
            token_mixers=nn.Identity,
            norm_layer=nn.BatchNorm2d,
            act_layer=nn.GELU,
            mlp_ratios=(4, 4, 4, 3),
            head_fn=MlpHead,
            drop_rate=0.,
            drop_path_rate=0.,
            ls_init_value=1e-6,
            **kwargs,
    ):
        super().__init__()

        num_stage = len(depths)
        if not isinstance(token_mixers, (list, tuple)):
            token_mixers = [token_mixers] * num_stage
        if not isinstance(mlp_ratios, (list, tuple)):
            mlp_ratios = [mlp_ratios] * num_stage


        self.num_classes = num_classes
        self.drop_rate = drop_rate
        self.stem = nn.Sequential(
            nn.Conv2d(in_chans, dims[0], kernel_size=4, stride=4),
            norm_layer(dims[0])
        )

        self.stages = nn.Sequential()
        dp_rates = [x.tolist() for x in torch.linspace(0, drop_path_rate, sum(depths)).split(depths)]
        stages = []
        prev_chs = dims[0]
        # feature resolution stages, each consisting of multiple residual blocks
        for i in range(num_stage):
            out_chs = dims[i]
            stages.append(MetaNeXtStage(
                prev_chs,
                out_chs,
                ds_stride=2 if i > 0 else 1, 
                depth=depths[i],
                drop_path_rates=dp_rates[i],
                ls_init_value=ls_init_value,
                act_layer=act_layer,
                token_mixer=token_mixers[i],
                norm_layer=norm_layer,
                mlp_ratio=mlp_ratios[i],
            ))
            prev_chs = out_chs
        self.stages = nn.Sequential(*stages)
        self.num_features = prev_chs
        self.head = head_fn(self.num_features, num_classes, drop=drop_rate)
        self.apply(self._init_weights)

    @torch.jit.ignore
    def set_grad_checkpointing(self, enable=True):
        for s in self.stages:
            s.grad_checkpointing = enable

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'norm'}
    

    def forward_features(self, x):
        x = self.stem(x)
        x = self.stages(x)
        return x

    def forward_head(self, x):
        x = self.head(x)
        return x

    def forward(self, x):
        x = self.forward_features(x)
        x = self.forward_head(x)
        return x


    def _init_weights(self, m):
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            trunc_normal_(m.weight, std=.02)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)



def _cfg(url='', **kwargs):
    return {
        'url': url,
        'num_classes': 1, 'input_size': (3, 224, 224), 'pool_size': (7, 7),
        'crop_pct': 0.875, 'interpolation': 'bicubic',
        'mean': IMAGENET_DEFAULT_MEAN, 'std': IMAGENET_DEFAULT_STD,
        'first_conv': 'stem.0', 'classifier': 'head.fc',
        **kwargs
    }


default_cfgs = dict(
    inceptionnext_tiny=_cfg(
        url='https://github.com/sail-sg/inceptionnext/releases/download/model/inceptionnext_tiny.pth',
    ),
    inceptionnext_small=_cfg(
        url='https://github.com/sail-sg/inceptionnext/releases/download/model/inceptionnext_small.pth',
    ),
    inceptionnext_base=_cfg(
        url='https://github.com/sail-sg/inceptionnext/releases/download/model/inceptionnext_base.pth',
    ),
    inceptionnext_base_384=_cfg(
        url='https://github.com/sail-sg/inceptionnext/releases/download/model/inceptionnext_base_384.pth',
        input_size=(3, 384, 384), crop_pct=1.0,
    ),
)


@register_model
def inceptionnext_tiny(pretrained=False, **kwargs):
    model = MetaNeXt(depths=(3, 3, 9, 3), dims=(96, 192, 384, 768), 
                      token_mixers=InceptionDWConv2d,
                      **kwargs
    )
    model.default_cfg = default_cfgs['inceptionnext_tiny']
    if pretrained:
        state_dict = torch.hub.load_state_dict_from_url(
            url=model.default_cfg['url'], map_location="cpu", check_hash=True)
        model.load_state_dict(state_dict)
    return model

@register_model
def inceptionnext_small(pretrained=False, **kwargs):
    model = MetaNeXt(depths=(3, 3, 27, 3), dims=(96, 192, 384, 768), 
                      token_mixers=InceptionDWConv2d,
                      **kwargs
    )
    model.default_cfg = default_cfgs['inceptionnext_small']
    if pretrained:
        state_dict = torch.hub.load_state_dict_from_url(
            url=model.default_cfg['url'], map_location="cpu", check_hash=True)
        model.load_state_dict(state_dict)
    return model

@register_model
def inceptionnext_base(pretrained=False, **kwargs):
    model = MetaNeXt(depths=(3, 3, 27, 3), dims=(128, 256, 512, 1024), 
                      token_mixers=InceptionDWConv2d,
                      **kwargs
    )
    model.default_cfg = default_cfgs['inceptionnext_base']
    if pretrained:
        state_dict = torch.hub.load_state_dict_from_url(
            url=model.default_cfg['url'], map_location="cpu", check_hash=True)
        model.load_state_dict(state_dict)
    return model

@register_model
def inceptionnext_base_384(pretrained=False, **kwargs):
    model = MetaNeXt(depths=[3, 3, 27, 3], dims=[128, 256, 512, 1024], 
                      mlp_ratios=[4, 4, 4, 3],
                      token_mixers=InceptionDWConv2d,
                      **kwargs
    )
    model.default_cfg = default_cfgs['inceptionnext_base_384']
    if pretrained:
        state_dict = torch.hub.load_state_dict_from_url(
            url=model.default_cfg['url'], map_location="cpu", check_hash=True)
        model.load_state_dict(state_dict)
    return model

# %%
x=inceptionnext_small()
x
# Out:
# MetaNeXt(
#   (stem): Sequential(
#     (0): Conv2d(1, 96, kernel_size=(4, 4), stride=(4, 4))
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stages): Sequential(
#     (0): MetaNeXtStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#             (dwconv_w): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#             (dwconv_h): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#             (dwconv_w): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#             (dwconv_h): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#             (dwconv_w): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#             (dwconv_h): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (1): MetaNeXtStage(
#       (downsample): Sequential(
#         (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#             (dwconv_w): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#             (dwconv_h): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#             (dwconv_w): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#             (dwconv_h): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#             (dwconv_w): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#             (dwconv_h): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (2): MetaNeXtStage(
#       (downsample): Sequential(
#         (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (3): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (4): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (5): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (6): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (7): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (8): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (9): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (10): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (11): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (12): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (13): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (14): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (15): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (16): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (17): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (18): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (19): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (20): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (21): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (22): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (23): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (24): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (25): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (26): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (3): MetaNeXtStage(
#       (downsample): Sequential(
#         (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#             (dwconv_w): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#             (dwconv_h): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#           )
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(768, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(2304, 768, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#             (dwconv_w): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#             (dwconv_h): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#           )
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(768, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(2304, 768, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#             (dwconv_w): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#             (dwconv_h): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#           )
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(768, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(2304, 768, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#   )
#   (head): MlpHead(
#     (fc1): Linear(in_features=768, out_features=2304, bias=True)
#     (act): GELU(approximate='none')
#     (norm): LayerNorm((2304,), eps=1e-06, elementwise_affine=True)
#     (fc2): Linear(in_features=2304, out_features=1, bias=True)
#     (drop): Dropout(p=0.0, inplace=False)
#   )
# )

# %%
from PIL import Image
import numpy as np
import torch
import torchvision.transforms as transforms

def processImage(image):
    # Load the image using Pillow (PIL)
    image = Image.open(image)

    # Resize the image to the desired size
    desired_width = 100
    transform = transforms.Compose([
        transforms.Resize((desired_width, desired_width)),
        transforms.ToTensor(),
    ])

    image_tensor = transform(image)

    # Add a batch dimension by unsqueezing
    image_tensor = image_tensor.unsqueeze(0)

    return image_tensor

# Print the shape of the resulting tensor
#print(image_tensor.shape)

# %%
x.default_cfg
# Out:
# {'url': 'https://github.com/sail-sg/inceptionnext/releases/download/model/inceptionnext_small.pth',
#  'num_classes': 1,
#  'input_size': (3, 224, 224),
#  'pool_size': (7, 7),
#  'crop_pct': 0.875,
#  'interpolation': 'bicubic',
#  'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),
#  'first_conv': 'stem.0',
#  'classifier': 'head.fc'}

# %%
#Test single image tensor
#Don't run this
x.train()

# Pass the input tensor through the model
with torch.no_grad():
    output = x(image_tensor)

for i in output[0]:
    print(i)
# Out:
# tensor(0.9137)

# %%
# Define model, loss function, and optimizer
model = inceptionnext_small()
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
#Don't run this
len(imageData)
# Out:
# 10675

# %%
#Testing filename loop for creating input dataset
#Don't run this
for i in range(len(imageData)):
    file_name = '../../data/siim-acr-pneumothorax/png_images' + imageData['new_filename'][i]
    print("filename: ", file_name)
# Out:
# filename:  ../../data/siim-acr-pneumothorax/png_images2_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images3_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images4_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images7_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images8_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images10_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images11_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images13_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images15_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images16_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images18_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images19_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images20_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images23_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images26_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images27_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images28_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images29_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images30_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images34_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images35_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images38_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images39_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images40_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images43_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images44_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images45_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images46_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images47_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images48_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images49_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images51_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images52_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images53_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images55_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images56_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images57_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images59_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images60_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images61_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images62_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images63_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images64_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images65_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images66_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images67_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images68_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images69_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images70_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images71_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images72_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images73_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images74_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images75_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images76_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images77_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images78_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images79_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images81_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images82_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images83_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images84_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images88_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images89_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images90_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images91_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images93_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images95_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images97_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images100_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images101_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images103_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images104_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images105_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images106_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images107_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images109_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images110_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images111_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images112_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images114_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images116_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images118_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images119_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images121_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images122_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images124_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images125_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images126_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images127_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images128_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images129_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images130_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images131_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images133_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images134_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images135_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images136_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images137_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images139_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images141_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images142_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images143_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images144_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images145_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images147_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images148_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images149_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images150_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images152_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images153_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images154_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images155_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images157_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images158_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images159_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images160_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images161_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images163_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images165_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images167_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images168_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images169_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images170_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images173_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images174_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images175_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images177_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images178_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images179_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images180_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images181_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images182_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images183_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images184_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images185_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images187_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images188_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images189_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images191_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images192_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images195_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images196_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images197_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images198_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images199_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images200_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images201_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images203_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images204_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images206_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images208_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images209_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images212_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images213_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images214_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images216_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images219_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images221_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images222_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images223_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images224_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images225_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images226_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images227_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images228_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images229_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images230_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images231_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images232_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images233_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images234_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images236_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images238_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images239_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images240_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images241_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images242_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images243_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images244_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images245_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images249_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images250_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images251_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images253_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images254_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images255_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images257_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images258_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images259_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images260_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_images261_train_1_.png
# filename:  ../../data/siim-acr-pneumothorax/png_
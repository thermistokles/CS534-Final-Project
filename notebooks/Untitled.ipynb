# %%
import torch
import timm
from timm import utils
import torch.nn as nn
from PIL import Image
from tqdm import tqdm
import torch.cuda
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, matthews_corrcoef
from sklearn.utils import resample
from imblearn.under_sampling import RandomUnderSampler

# %%
seed = 42

# %%
model = 'inception_next_small'

# %%
model = timm.create_model(model, pretrained=True)

# %%
#Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

device
# Out:
# device(type='cpu')

# %%
if torch.cuda.is_available():
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True
    torch.cuda.manual_seed(seed)

np.random.seed(seed)
utils.random_seed(seed, 0)
torch.manual_seed(seed)

# %%
model.head.fc2 = nn.Linear(in_features=2304, out_features=1, bias=True)

# %%
print(model)
# Out:
# MetaNeXt(
#   (stem): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stages): Sequential(
#     (0): MetaNeXtStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#             (dwconv_w): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#             (dwconv_h): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#             (dwconv_w): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#             (dwconv_h): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#             (dwconv_w): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#             (dwconv_h): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (1): MetaNeXtStage(
#       (downsample): Sequential(
#         (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#             (dwconv_w): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#             (dwconv_h): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#             (dwconv_w): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#             (dwconv_h): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#             (dwconv_w): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#             (dwconv_h): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (2): MetaNeXtStage(
#       (downsample): Sequential(
#         (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (3): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (4): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (5): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (6): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (7): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (8): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (9): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (10): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (11): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (12): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (13): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (14): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (15): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (16): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (17): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (18): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (19): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (20): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (21): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (22): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (23): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (24): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (25): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (26): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#             (dwconv_w): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#             (dwconv_h): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (3): MetaNeXtStage(
#       (downsample): Sequential(
#         (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#             (dwconv_w): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#             (dwconv_h): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#           )
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(768, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(2304, 768, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#             (dwconv_w): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#             (dwconv_h): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#           )
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(768, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(2304, 768, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): InceptionDWConv2d(
#             (dwconv_hw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#             (dwconv_w): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#             (dwconv_h): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#           )
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): ConvMlp(
#             (fc1): Conv2d(768, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): GELU(approximate='none')
#             (drop): Dropout(p=0.0, inplace=False)
#             (fc2): Conv2d(2304, 768, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#   )
#   (head): MlpClassifierHead(
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc1): Linear(in_features=768, out_features=2304, bias=True)
#     (act): GELU(approximate='none')
#     (norm): LayerNorm((2304,), eps=1e-06, elementwise_affine=True)
#     (fc2): Linear(in_features=2304, out_features=1, bias=True)
#     (drop): Dropout(p=0.0, inplace=False)
#   )
# )

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

class CustomDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx])
        if self.transform:
            image = self.transform(image)
        label = self.labels[idx]
        return image, label

# Define a transformation to resize and normalize your images
# Define a transformation to resize and normalize your grayscale images
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Adjust to your model's input size
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  # Mean and std for grayscale images
])

# %%
imageData=pd.read_csv('../../data/siim-acr-pneumothorax/stage_1_train_images.csv')

# %%
imageData
# Out:
#              new_filename                                            ImageId  \
# 0          0_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.5597.151787518...
# 1          1_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.12515.15178752...
# 2          2_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.4904.151787518...
# 3          3_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.32579.15178751...
# 4          4_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.1314.151787516...
# ...                   ...                                                ...
# 10670  10670_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.32459.15178751...
# 10671  10671_train_1_.png  1.2.276.0.7230010.3.1.4.8323329.4461.151787518...
# 10672  10672_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.32730.15178751...
# 10673  10673_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.13252.15178752...
# 10674  10674_train_0_.png  1.2.276.0.7230010.3.1.4.8323329.12050.15178752...
#
#        has_pneumo
# 0               0
# 1               0
# 2               1
# 3               1
# 4               1
# ...           ...
# 10670           1
# 10671           1
# 10672           0
# 10673           0
# 10674           0
#
# [10675 rows x 3 columns]

# %%
type(imageData['has_pneumo'])
# Out:
# pandas.core.series.Series

# %%
# majority_class = imageData[imageData['has_pneumo'] == 0]
# minority_class = imageData[imageData['has_pneumo'] == 1]

# # Undersample the majority class randomly
# undersampled_majority = resample(majority_class, replace=False, n_samples=len(minority_class), random_state=42)

# # Combine the undersampled majority class with the minority class
# undersampled_data = pd.concat([undersampled_majority, minority_class])

# # Shuffle the combined dataset
# undersampled_data = undersampled_data.sample(frac=1, random_state=42)

# # Separate features and labels
# X_undersampled = undersampled_data.drop('has_pneumo', axis=1)
# y_undersampled = undersampled_data['has_pneumo']

# %%
# Apply random undersampling
rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(imageData, imageData['has_pneumo'])

# %%
len(X_resampled)
# Out:
# 4758

# %%
y_resampled.value_counts()
# Out:
# 0    2379
# 1    2379
# Name: has_pneumo, dtype: int64

# %%
#Test the model output

# %%
in_features = model.head.fc1.in_features

# %%
in_features
# Out:
# 768

# %%
model.head.fc1 = nn.Linear(in_features, 1)

# %%
model.head.fc1 = nn.Linear(in_features, 1)  # Change 1 to the desired number of output units for binary classification
model.head.fc2 = None  # Remove the existing fc2 layer
model.head.act = None  # Remove the existing activation function
model.head.norm = None  # Remove the existing normalization layer
model.head.drop = None  # Remove the existing dropout layer

# %%
model.head = nn.Sequential(model.head, nn.Sigmoid())

# %%
model.head
# Out:
# Sequential(
#   (0): MlpClassifierHead(
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc1): Linear(in_features=768, out_features=1, bias=True)
#     (act): None
#     (norm): None
#     (fc2): None
#     (drop): None
#   )
#   (1): Sigmoid()
# )

# %%
import os

data_dir = './img'
image_filenames = os.listdir(data_dir)  # List of image file names in your data directory

# %%
image_filenames = os.listdir(data_dir)

# %%
image = Image.open(image_filenames[0]).convert("RGB")
if transform:
    image = transform(image).unsqueeze(0)

# %%
in_features = model.head.fc1.in_features
model.head.fc1 = nn.Linear(in_features, 1)  # Change 1 to the desired number of output units for binary classification
model.head.fc2 = None  # Remove the existing fc2 layer
model.head.act = nn.Sigmoid()  # Remove the existing activation function
model.head.norm = None  # Remove the existing normalization layer
model.head.drop = None  # Remove the existing dropout layer

# Add a sigmoid activation after the linear layer
model.head = nn.Sequential(model.head, nn.Sigmoid())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 in_features = model.head.fc1.in_features
#       2 model.head.fc1 = nn.Linear(in_features, 1)  # Change 1 to the desired number of output units for binary classification
#       3 model.head.fc2 = None  # Remove the existing fc2 layer
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'Sequential' object has no attribute 'fc1'

# %%
with torch.no_grad():
    output = model(image)

# %%
output
# Out:
# tensor([[-0.1408]])

# %%
probabilities = torch.sigmoid(output)

# %%
probabilities_np = probabilities.cpu().numpy()

# %%
probabilities_np
# Out:
# array([[0.1944529 , 0.12688074, 0.47426674, 0.3570304 , 0.43011683,
#         0.27928212, 0.3487352 , 0.1443054 , 0.10633117, 0.23080988,
#         0.22035547, 0.3930462 , 0.30229175, 0.30200794, 0.29173818,
#         0.18936107, 0.42003483, 0.11973131, 0.11265685, 0.31094584,
#         0.28104022, 0.20780575, 0.18153124, 0.34598833, 0.07790019,
#         0.16849488, 0.19085152, 0.2796657 , 0.24795033, 0.16777332,
#         0.1105394 , 0.23386014, 0.18014613, 0.27601987, 0.4657362 ,
#         0.23649836, 0.30823064, 0.41483298, 0.24571967, 0.42248505,
#         0.36977914, 0.21349762, 0.46984157, 0.48519972, 0.24627115,
#         0.43426722, 0.30039585, 0.3290155 , 0.24648905, 0.16743891,
#         0.33002606, 0.2480108 , 0.35494632, 0.31827655, 0.04518311,
#         0.16257612, 0.14439799, 0.08628424, 0.12917407, 0.23729086,
#         0.11803191, 0.2662952 , 0.18444994, 0.48270223, 0.14426611,
#         0.17128058, 0.15012835, 0.10359113, 0.18416171, 0.859488  ,
#         0.19759932, 0.79381526, 0.17656767, 0.20949265, 0.20894745,
#         0.25005305, 0.45802706, 0.26642483, 0.39179513, 0.3983934 ,
#         0.19145153, 0.12507334, 0.15471128, 0.2505819 , 0.28008595,
epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch + 1}/{num_epochs}"):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Update statistics
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct_predictions += (predicted == labels).sum().item()
        total_samples += labels.size(0)

    # Calculate and print the average loss and accuracy for the epoch
    epoch_loss = running_loss / len(train_dataloader)
    epoch_accuracy = correct_predictions / total_samples

    print(f"Epoch {epoch + 1}/{num_epochs} - Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy * 100:.2f}%")
# Out:
# Epoch 1/10:   0%|                                                                                                                                                                       | 0/107 [01:30<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 13
#      11 outputs = model(inputs)
#      12 loss = criterion(outputs, labels)
# ---> 13 loss.backward()
#      14 optimizer.step()
#      16 # Update statistics
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
#Testing

# %%
imageData=pd.read_csv('../../data/siim-acr-pneumothorax/stage_1_test_images.csv')

# %%
imageData
# Out:
#           new_filename                                            ImageId  \
# 0        0_test_1_.png  1.2.276.0.7230010.3.1.4.8323329.5797.151787519...
# 1        1_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.5798.151787519...
# 2        2_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.5799.151787519...
# 3        3_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.580.1517875163...
# 4        4_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.5800.151787519...
# ...                ...                                                ...
# 1367  1367_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.7049.151787520...
# 1368  1368_test_1_.png  1.2.276.0.7230010.3.1.4.8323329.705.1517875164...
# 1369  1369_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.7050.151787520...
# 1370  1370_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.7051.151787520...
# 1371  1371_test_0_.png  1.2.276.0.7230010.3.1.4.8323329.7052.151787520...
#
#       has_pneumo
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1367           0
# 1368           1
# 1369           0
# 1370           0
# 1371           0
#
# [1372 rows x 3 columns]

# %%
labels = imageData['has_pneumo']

# %%
image_paths = []

for i in range(len(imageData)):
    file_name = '../../data/siim-acr-pneumothorax/png_images/' + imageData['new_filename'][i]
    image_paths.append(file_name)

# %%
custom_dataset = CustomDataset(image_paths, labels, transform=transform)

# %%
test_loader = DataLoader(custom_dataset, batch_size=100, shuffle=True)

# %%
correct_predictions = 0
total_samples = 0
all_predicted = []
all_labels = []

# %%
with torch.no_grad():
    for images, labels in tqdm(test_loader, desc="Testing")::
        #images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = x(images)
        predicted = (outputs > 0.5).float()  # Assuming binary classification
        total_samples += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()
        
        #Move the predictions to CPU for processing SciKitLearn
        all_predicted.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        
accuracy = accuracy_score(all_labels, all_predicted)
f1 = f1_score(all_labels, all_predicted)
conf_matrix = confusion_matrix(all_labels, all_predicted)
mcc = matthews_corrcoef(all_labels, all_predicted)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
print(f"MCC Score: {mcc:.4f}")
